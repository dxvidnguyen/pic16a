# %% [markdown]
# Multinominal Logistic Regression

# %%
#import libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import tree, preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
#penguins data
url = "https://philchodrow.github.io/PIC16A/datasets/palmer_penguins.csv"
penguins = pd.read_csv(url)
penguins.head()

#need to prep data
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion  Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/07
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/07
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/07
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/07
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/07
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
#dropping columns: studyName, Individual ID, Date Egg, Sample Number
pdata = penguins.drop(['studyName', 'Individual ID', 'Date Egg', 'Sample Number', 'Comments'], axis = 1)
pdata.head()
# Out:
#                                Species  Region     Island               Stage  \
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 3  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
#
#   Clutch Completion  Culmen Length (mm)  Culmen Depth (mm)  \
# 0               Yes                39.1               18.7
# 1               Yes                39.5               17.4
# 2               Yes                40.3               18.0
# 3               Yes                 NaN                NaN
# 4               Yes                36.7               19.3
#
#    Flipper Length (mm)  Body Mass (g)     Sex  Delta 15 N (o/oo)  \
# 0                181.0         3750.0    MALE                NaN
# 1                186.0         3800.0  FEMALE            8.94956
# 2                195.0         3250.0  FEMALE            8.36821
# 3                  NaN            NaN     NaN                NaN
# 4                193.0         3450.0  FEMALE            8.76651
#
#    Delta 13 C (o/oo)
# 0                NaN
# 1          -24.69454
# 2          -25.33302
# 3                NaN
# 4          -25.32426

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Species              344 non-null    object
#  1   Region               344 non-null    object
#  2   Island               344 non-null    object
#  3   Stage                344 non-null    object
#  4   Clutch Completion    344 non-null    object
#  5   Culmen Length (mm)   342 non-null    float64
#  6   Culmen Depth (mm)    342 non-null    float64
#  7   Flipper Length (mm)  342 non-null    float64
#  8   Body Mass (g)        342 non-null    float64
#  9   Sex                  334 non-null    object
#  10  Delta 15 N (o/oo)    330 non-null    float64
#  11  Delta 13 C (o/oo)    331 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 32.4+ KB

# %%
#drop nan values
data = pdata.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 1 to 343
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Species              325 non-null    object
#  1   Region               325 non-null    object
#  2   Island               325 non-null    object
#  3   Stage                325 non-null    object
#  4   Clutch Completion    325 non-null    object
#  5   Culmen Length (mm)   325 non-null    float64
#  6   Culmen Depth (mm)    325 non-null    float64
#  7   Flipper Length (mm)  325 non-null    float64
#  8   Body Mass (g)        325 non-null    float64
#  9   Sex                  325 non-null    object
#  10  Delta 15 N (o/oo)    325 non-null    float64
#  11  Delta 13 C (o/oo)    325 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 33.0+ KB

# %%
data.head()
# Out:
#                                Species  Region     Island               Stage  \
# 1  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 2  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 4  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 5  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
# 6  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen  Adult, 1 Egg Stage
#
#   Clutch Completion  Culmen Length (mm)  Culmen Depth (mm)  \
# 1               Yes                39.5               17.4
# 2               Yes                40.3               18.0
# 4               Yes                36.7               19.3
# 5               Yes                39.3               20.6
# 6                No                38.9               17.8
#
#    Flipper Length (mm)  Body Mass (g)     Sex  Delta 15 N (o/oo)  \
# 1                186.0         3800.0  FEMALE            8.94956
# 2                195.0         3250.0  FEMALE            8.36821
# 4                193.0         3450.0  FEMALE            8.76651
# 5                190.0         3650.0    MALE            8.66496
# 6                181.0         3625.0  FEMALE            9.18718
#
#    Delta 13 C (o/oo)
# 1          -24.69454
# 2          -25.33302
# 4          -25.32426
# 5          -25.29805
# 6          -25.21799

# %%
for index, row in data.iterrows():
    print("row : " + str(row))
    print("index : " + str(index))
# Out:
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.5
# Culmen Depth (mm)                                     17.4
# Flipper Length (mm)                                    186
# Body Mass (g)                                         3800
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.94956
# Delta 13 C (o/oo)                                 -24.6945
# Name: 1, dtype: object
# index : 1
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.3
# Culmen Depth (mm)                                       18
# Flipper Length (mm)                                    195
# Body Mass (g)                                         3250
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.36821
# Delta 13 C (o/oo)                                  -25.333
# Name: 2, dtype: object
# index : 2
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    36.7
# Culmen Depth (mm)                                     19.3
# Flipper Length (mm)                                    193
# Body Mass (g)                                         3450
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.76651
# Delta 13 C (o/oo)                                 -25.3243
# Name: 4, dtype: object
# index : 4
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.3
# Culmen Depth (mm)                                     20.6
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3650
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.66496
# Delta 13 C (o/oo)                                  -25.298
# Name: 5, dtype: object
# index : 5
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    38.9
# Culmen Depth (mm)                                     17.8
# Flipper Length (mm)                                    181
# Body Mass (g)                                         3625
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.18718
# Delta 13 C (o/oo)                                  -25.218
# Name: 6, dtype: object
# index : 6
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    39.2
# Culmen Depth (mm)                                     19.6
# Flipper Length (mm)                                    195
# Body Mass (g)                                         4675
# Sex                                                   MALE
# Delta 15 N (o/oo)                                   9.4606
# Delta 13 C (o/oo)                                 -24.8996
# Name: 7, dtype: object
# index : 7
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    34.6
# Culmen Depth (mm)                                     21.1
# Flipper Length (mm)                                    198
# Body Mass (g)                                         4400
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.55583
# Delta 13 C (o/oo)                                 -25.2259
# Name: 14, dtype: object
# index : 14
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    38.7
# Culmen Depth (mm)                                       19
# Flipper Length (mm)                                    195
# Body Mass (g)                                         3450
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.18528
# Delta 13 C (o/oo)                                 -25.0669
# Name: 16, dtype: object
# index : 16
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    42.5
# Culmen Depth (mm)                                     20.7
# Flipper Length (mm)                                    197
# Body Mass (g)                                         4500
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.67538
# Delta 13 C (o/oo)                                 -25.1399
# Name: 17, dtype: object
# index : 17
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    34.4
# Culmen Depth (mm)                                     18.4
# Flipper Length (mm)                                    184
# Body Mass (g)                                         3325
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.47827
# Delta 13 C (o/oo)                                 -25.2332
# Name: 18, dtype: object
# index : 18
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      46
# Culmen Depth (mm)                                     21.5
# Flipper Length (mm)                                    194
# Body Mass (g)                                         4200
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.11616
# Delta 13 C (o/oo)                                 -24.7723
# Name: 19, dtype: object
# index : 19
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    37.8
# Culmen Depth (mm)                                     18.3
# Flipper Length (mm)                                    174
# Body Mass (g)                                         3400
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.73762
# Delta 13 C (o/oo)                                 -25.0938
# Name: 20, dtype: object
# index : 20
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    37.7
# Culmen Depth (mm)                                     18.7
# Flipper Length (mm)                                    180
# Body Mass (g)                                         3600
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.66271
# Delta 13 C (o/oo)                                 -25.0639
# Name: 21, dtype: object
# index : 21
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    35.9
# Culmen Depth (mm)                                     19.2
# Flipper Length (mm)                                    189
# Body Mass (g)                                         3800
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.22286
# Delta 13 C (o/oo)                                 -25.0347
# Name: 22, dtype: object
# index : 22
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    38.2
# Culmen Depth (mm)                                     18.1
# Flipper Length (mm)                                    185
# Body Mass (g)                                         3950
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.43423
# Delta 13 C (o/oo)                                 -25.2266
# Name: 23, dtype: object
# index : 23
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    38.8
# Culmen Depth (mm)                                     17.2
# Flipper Length (mm)                                    180
# Body Mass (g)                                         3800
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.63954
# Delta 13 C (o/oo)                                 -25.2986
# Name: 24, dtype: object
# index : 24
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    35.3
# Culmen Depth (mm)                                     18.9
# Flipper Length (mm)                                    187
# Body Mass (g)                                         3800
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.21292
# Delta 13 C (o/oo)                                 -24.3613
# Name: 25, dtype: object
# index : 25
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.6
# Culmen Depth (mm)                                     18.6
# Flipper Length (mm)                                    183
# Body Mass (g)                                         3550
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.93997
# Delta 13 C (o/oo)                                 -25.3629
# Name: 26, dtype: object
# index : 26
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.5
# Culmen Depth (mm)                                     17.9
# Flipper Length (mm)                                    187
# Body Mass (g)                                         3200
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.08138
# Delta 13 C (o/oo)                                 -25.4945
# Name: 27, dtype: object
# index : 27
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    37.9
# Culmen Depth (mm)                                     18.6
# Flipper Length (mm)                                    172
# Body Mass (g)                                         3150
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.38404
# Delta 13 C (o/oo)                                 -25.1984
# Name: 28, dtype: object
# index : 28
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    40.5
# Culmen Depth (mm)                                     18.9
# Flipper Length (mm)                                    180
# Body Mass (g)                                         3950
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.90027
# Delta 13 C (o/oo)                                 -25.1161
# Name: 29, dtype: object
# index : 29
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.5
# Culmen Depth (mm)                                     16.7
# Flipper Length (mm)                                    178
# Body Mass (g)                                         3250
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.69756
# Delta 13 C (o/oo)                                 -25.1122
# Name: 30, dtype: object
# index : 30
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    37.2
# Culmen Depth (mm)                                     18.1
# Flipper Length (mm)                                    178
# Body Mass (g)                                         3900
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.72764
# Delta 13 C (o/oo)                                 -25.0102
# Name: 31, dtype: object
# index : 31
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.5
# Culmen Depth (mm)                                     17.8
# Flipper Length (mm)                                    188
# Body Mass (g)                                         3300
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.66523
# Delta 13 C (o/oo)                                 -25.0602
# Name: 32, dtype: object
# index : 32
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.9
# Culmen Depth (mm)                                     18.9
# Flipper Length (mm)                                    184
# Body Mass (g)                                         3900
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.79665
# Delta 13 C (o/oo)                                 -25.1459
# Name: 33, dtype: object
# index : 33
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    36.4
# Culmen Depth (mm)                                       17
# Flipper Length (mm)                                    195
# Body Mass (g)                                         3325
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.17847
# Delta 13 C (o/oo)                                 -25.2306
# Name: 34, dtype: object
# index : 34
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.2
# Culmen Depth (mm)                                     21.1
# Flipper Length (mm)                                    196
# Body Mass (g)                                         4150
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.15308
# Delta 13 C (o/oo)                                 -25.0347
# Name: 35, dtype: object
# index : 35
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    38.8
# Culmen Depth (mm)                                       20
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3950
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.18985
# Delta 13 C (o/oo)                                 -25.1226
# Name: 36, dtype: object
# index : 36
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    42.2
# Culmen Depth (mm)                                     18.5
# Flipper Length (mm)                                    180
# Body Mass (g)                                         3550
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.04787
# Delta 13 C (o/oo)                                 -25.4952
# Name: 37, dtype: object
# index : 37
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    37.6
# Culmen Depth (mm)                                     19.3
# Flipper Length (mm)                                    181
# Body Mass (g)                                         3300
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.41131
# Delta 13 C (o/oo)                                 -25.0417
# Name: 38, dtype: object
# index : 38
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    36.5
# Culmen Depth (mm)                                       18
# Flipper Length (mm)                                    182
# Body Mass (g)                                         3150
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.68933
# Delta 13 C (o/oo)                                 -24.4228
# Name: 40, dtype: object
# index : 40
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      36
# Culmen Depth (mm)                                     18.5
# Flipper Length (mm)                                    186
# Body Mass (g)                                         3100
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.50772
# Delta 13 C (o/oo)                                 -25.0349
# Name: 42, dtype: object
# index : 42
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    44.1
# Culmen Depth (mm)                                     19.7
# Flipper Length (mm)                                    196
# Body Mass (g)                                         4400
# Sex                                                   MALE
# Delta 15 N (o/oo)                                   9.2372
# Delta 13 C (o/oo)                                  -24.527
# Name: 43, dtype: object
# index : 43
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      37
# Culmen Depth (mm)                                     16.9
# Flipper Length (mm)                                    185
# Body Mass (g)                                         3000
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.36392
# Delta 13 C (o/oo)                                 -25.0175
# Name: 44, dtype: object
# index : 44
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.6
# Culmen Depth (mm)                                     18.8
# Flipper Length (mm)                                    190
# Body Mass (g)                                         4600
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.49106
# Delta 13 C (o/oo)                                 -24.1026
# Name: 45, dtype: object
# index : 45
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      36
# Culmen Depth (mm)                                     17.9
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3450
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.51784
# Delta 13 C (o/oo)                                 -25.0768
# Name: 48, dtype: object
# index : 48
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                               Dream
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    42.3
# Culmen Depth (mm)                                     21.2
# Flipper Length (mm)                                    191
# Body Mass (g)                                         4150
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.87988
# Delta 13 C (o/oo)                                 -25.1854
# Name: 49, dtype: object
# index : 49
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.6
# Culmen Depth (mm)                                     17.7
# Flipper Length (mm)                                    186
# Body Mass (g)                                         3500
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.46616
# Delta 13 C (o/oo)                                 -26.1299
# Name: 50, dtype: object
# index : 50
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.1
# Culmen Depth (mm)                                     18.9
# Flipper Length (mm)                                    188
# Body Mass (g)                                         4300
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.51362
# Delta 13 C (o/oo)                                  -26.556
# Name: 51, dtype: object
# index : 51
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      35
# Culmen Depth (mm)                                     17.9
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3450
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.19539
# Delta 13 C (o/oo)                                 -26.1721
# Name: 52, dtype: object
# index : 52
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      42
# Culmen Depth (mm)                                     19.5
# Flipper Length (mm)                                    200
# Body Mass (g)                                         4050
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.48095
# Delta 13 C (o/oo)                                 -26.3146
# Name: 53, dtype: object
# index : 53
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    34.5
# Culmen Depth (mm)                                     18.1
# Flipper Length (mm)                                    187
# Body Mass (g)                                         2900
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.41837
# Delta 13 C (o/oo)                                 -26.5472
# Name: 54, dtype: object
# index : 54
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    41.4
# Culmen Depth (mm)                                     18.6
# Flipper Length (mm)                                    191
# Body Mass (g)                                         3700
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.35396
# Delta 13 C (o/oo)                                 -26.2785
# Name: 55, dtype: object
# index : 55
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                      39
# Culmen Depth (mm)                                     17.5
# Flipper Length (mm)                                    186
# Body Mass (g)                                         3550
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.57199
# Delta 13 C (o/oo)                                 -26.0719
# Name: 56, dtype: object
# index : 56
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.6
# Culmen Depth (mm)                                     18.8
# Flipper Length (mm)                                    193
# Body Mass (g)                                         3800
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.56674
# Delta 13 C (o/oo)                                 -25.9884
# Name: 57, dtype: object
# index : 57
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    36.5
# Culmen Depth (mm)                                     16.6
# Flipper Length (mm)                                    181
# Body Mass (g)                                         2850
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  9.07878
# Delta 13 C (o/oo)                                 -25.8816
# Name: 58, dtype: object
# index : 58
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    37.6
# Culmen Depth (mm)                                     19.1
# Flipper Length (mm)                                    194
# Body Mass (g)                                         3750
# Sex                                                   MALE
# Delta 15 N (o/oo)                                    9.108
# Delta 13 C (o/oo)                                 -25.8968
# Name: 59, dtype: object
# index : 59
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    35.7
# Culmen Depth (mm)                                     16.9
# Flipper Length (mm)                                    185
# Body Mass (g)                                         3150
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.96472
# Delta 13 C (o/oo)                                 -26.4094
# Name: 60, dtype: object
# index : 60
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    41.3
# Culmen Depth (mm)                                     21.1
# Flipper Length (mm)                                    195
# Body Mass (g)                                         4400
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.74802
# Delta 13 C (o/oo)                                 -26.3781
# Name: 61, dtype: object
# index : 61
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    37.6
# Culmen Depth (mm)                                       17
# Flipper Length (mm)                                    185
# Body Mass (g)                                         3600
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.58063
# Delta 13 C (o/oo)                                 -26.2157
# Name: 62, dtype: object
# index : 62
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    41.1
# Culmen Depth (mm)                                     18.2
# Flipper Length (mm)                                    192
# Body Mass (g)                                         4050
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.62264
# Delta 13 C (o/oo)                                 -26.6002
# Name: 63, dtype: object
# index : 63
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    36.4
# Culmen Depth (mm)                                     17.1
# Flipper Length (mm)                                    184
# Body Mass (g)                                         2850
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.62623
# Delta 13 C (o/oo)                                 -26.1165
# Name: 64, dtype: object
# index : 64
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    41.6
# Culmen Depth (mm)                                       18
# Flipper Length (mm)                                    192
# Body Mass (g)                                         3950
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.85562
# Delta 13 C (o/oo)                                 -26.0929
# Name: 65, dtype: object
# index : 65
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    35.5
# Culmen Depth (mm)                                     16.2
# Flipper Length (mm)                                    195
# Body Mass (g)                                         3350
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.56192
# Delta 13 C (o/oo)                                 -25.9554
# Name: 66, dtype: object
# index : 66
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                              Biscoe
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    41.1
# Culmen Depth (mm)                                     19.1
# Flipper Length (mm)                                    188
# Body Mass (g)                                         4100
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.71078
# Delta 13 C (o/oo)                                 -25.8101
# Name: 67, dtype: object
# index : 67
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    35.9
# Culmen Depth (mm)                                     16.6
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3050
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.47781
# Delta 13 C (o/oo)                                 -26.0782
# Name: 68, dtype: object
# index : 68
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                       No
# Culmen Length (mm)                                    41.8
# Culmen Depth (mm)                                     19.4
# Flipper Length (mm)                                    198
# Body Mass (g)                                         4450
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.86853
# Delta 13 C (o/oo)                                 -26.0621
# Name: 69, dtype: object
# index : 69
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    33.5
# Culmen Depth (mm)                                       19
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3600
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  7.88863
# Delta 13 C (o/oo)                                 -26.6308
# Name: 70, dtype: object
# index : 70
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.7
# Culmen Depth (mm)                                     18.4
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3900
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  9.29808
# Delta 13 C (o/oo)                                 -25.2345
# Name: 71, dtype: object
# index : 71
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    39.6
# Culmen Depth (mm)                                     17.2
# Flipper Length (mm)                                    196
# Body Mass (g)                                         3550
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.33524
# Delta 13 C (o/oo)                                 -26.5535
# Name: 72, dtype: object
# index : 72
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    45.8
# Culmen Depth (mm)                                     18.9
# Flipper Length (mm)                                    197
# Body Mass (g)                                         4150
# Sex                                                   MALE
# Delta 15 N (o/oo)                                  8.18658
# Delta 13 C (o/oo)                                 -26.4598
# Name: 73, dtype: object
# index : 73
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    35.5
# Culmen Depth (mm)                                     17.5
# Flipper Length (mm)                                    190
# Body Mass (g)                                         3700
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.70642
# Delta 13 C (o/oo)                                   -26.15
# Name: 74, dtype: object
# index : 74
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    42.8
# Culmen Depth (mm)                                     18.5
# Flipper Length (mm)                                    195
# Body Mass (g)                                         4250
# Sex                                                   MALE
# Delta 15 N (o/oo)                                   8.2993
# Delta 13 C (o/oo)                                 -26.3899
# Name: 75, dtype: object
# index : 75
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# Region                                              Anvers
# Island                                           Torgersen
# Stage                                   Adult, 1 Egg Stage
# Clutch Completion                                      Yes
# Culmen Length (mm)                                    40.9
# Culmen Depth (mm)                                     16.8
# Flipper Length (mm)                                    191
# Body Mass (g)                                         3700
# Sex                                                 FEMALE
# Delta 15 N (o/oo)                                  8.47257
# Delta 13 C (o/oo)                                   -26.02
# Name: 76, dtype: object
# index : 76
# row : Species                Adelie Penguin (Pygoscelis adeliae)
# ...
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  48.5
# Culmen Depth (mm)                                     15
# Flipper Length (mm)                                  219
# Body Mass (g)                                       4850
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.10231
# Delta 13 C (o/oo)                               -26.1876
# Name: 320, dtype: object
# index : 320
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  55.9
# Culmen Depth (mm)                                     17
# Flipper Length (mm)                                  228
# Body Mass (g)                                       5600
# Sex                                                 MALE
# Delta 15 N (o/oo)                                 8.3118
# Delta 13 C (o/oo)                               -26.3543
# Name: 321, dtype: object
# index : 321
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  47.2
# Culmen Depth (mm)                                   15.5
# Flipper Length (mm)                                  215
# Body Mass (g)                                       4975
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.30817
# Delta 13 C (o/oo)                               -26.2165
# Name: 322, dtype: object
# index : 322
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  49.1
# Culmen Depth (mm)                                     15
# Flipper Length (mm)                                  228
# Body Mass (g)                                       5500
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.65914
# Delta 13 C (o/oo)                                -25.792
# Name: 323, dtype: object
# index : 323
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  46.8
# Culmen Depth (mm)                                   16.1
# Flipper Length (mm)                                  215
# Body Mass (g)                                       5500
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.32359
# Delta 13 C (o/oo)                               -26.0576
# Name: 325, dtype: object
# index : 325
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  41.7
# Culmen Depth (mm)                                   14.7
# Flipper Length (mm)                                  210
# Body Mass (g)                                       4700
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.12311
# Delta 13 C (o/oo)                               -26.4481
# Name: 326, dtype: object
# index : 326
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  53.4
# Culmen Depth (mm)                                   15.8
# Flipper Length (mm)                                  219
# Body Mass (g)                                       5500
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.41017
# Delta 13 C (o/oo)                               -26.3387
# Name: 327, dtype: object
# index : 327
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  43.3
# Culmen Depth (mm)                                     14
# Flipper Length (mm)                                  208
# Body Mass (g)                                       4575
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                 8.4207
# Delta 13 C (o/oo)                               -26.3809
# Name: 328, dtype: object
# index : 328
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  48.1
# Culmen Depth (mm)                                   15.1
# Flipper Length (mm)                                  209
# Body Mass (g)                                       5500
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.45738
# Delta 13 C (o/oo)                               -26.2266
# Name: 329, dtype: object
# index : 329
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  50.5
# Culmen Depth (mm)                                   15.2
# Flipper Length (mm)                                  216
# Body Mass (g)                                       5000
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.24691
# Delta 13 C (o/oo)                               -26.1847
# Name: 330, dtype: object
# index : 330
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  49.8
# Culmen Depth (mm)                                   15.9
# Flipper Length (mm)                                  229
# Body Mass (g)                                       5950
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.29226
# Delta 13 C (o/oo)                               -26.2102
# Name: 331, dtype: object
# index : 331
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  43.5
# Culmen Depth (mm)                                   15.2
# Flipper Length (mm)                                  213
# Body Mass (g)                                       4650
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.21634
# Delta 13 C (o/oo)                               -26.1105
# Name: 332, dtype: object
# index : 332
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  51.5
# Culmen Depth (mm)                                   16.3
# Flipper Length (mm)                                  230
# Body Mass (g)                                       5500
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.78557
# Delta 13 C (o/oo)                               -25.7615
# Name: 333, dtype: object
# index : 333
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  46.2
# Culmen Depth (mm)                                   14.1
# Flipper Length (mm)                                  217
# Body Mass (g)                                       4375
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.30231
# Delta 13 C (o/oo)                               -25.9601
# Name: 334, dtype: object
# index : 334
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  55.1
# Culmen Depth (mm)                                     16
# Flipper Length (mm)                                  230
# Body Mass (g)                                       5850
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.08354
# Delta 13 C (o/oo)                               -26.1816
# Name: 335, dtype: object
# index : 335
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  44.5
# Culmen Depth (mm)                                   15.7
# Flipper Length (mm)                                  217
# Body Mass (g)                                       4875
# Sex                                                    .
# Delta 15 N (o/oo)                                8.04111
# Delta 13 C (o/oo)                               -26.1844
# Name: 336, dtype: object
# index : 336
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  48.8
# Culmen Depth (mm)                                   16.2
# Flipper Length (mm)                                  222
# Body Mass (g)                                       6000
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.33825
# Delta 13 C (o/oo)                               -25.8855
# Name: 337, dtype: object
# index : 337
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                     No
# Culmen Length (mm)                                  47.2
# Culmen Depth (mm)                                   13.7
# Flipper Length (mm)                                  214
# Body Mass (g)                                       4925
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                7.99184
# Delta 13 C (o/oo)                               -26.2054
# Name: 338, dtype: object
# index : 338
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  46.8
# Culmen Depth (mm)                                   14.3
# Flipper Length (mm)                                  215
# Body Mass (g)                                       4850
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.41151
# Delta 13 C (o/oo)                               -26.1383
# Name: 340, dtype: object
# index : 340
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  50.4
# Culmen Depth (mm)                                   15.7
# Flipper Length (mm)                                  222
# Body Mass (g)                                       5750
# Sex                                                 MALE
# Delta 15 N (o/oo)                                8.30166
# Delta 13 C (o/oo)                               -26.0412
# Name: 341, dtype: object
# index : 341
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  45.2
# Culmen Depth (mm)                                   14.8
# Flipper Length (mm)                                  212
# Body Mass (g)                                       5200
# Sex                                               FEMALE
# Delta 15 N (o/oo)                                8.24246
# Delta 13 C (o/oo)                               -26.1197
# Name: 342, dtype: object
# index : 342
# row : Species                Gentoo penguin (Pygoscelis papua)
# Region                                            Anvers
# Island                                            Biscoe
# Stage                                 Adult, 1 Egg Stage
# Clutch Completion                                    Yes
# Culmen Length (mm)                                  49.9
# Culmen Depth (mm)                                   16.1
# Flipper Length (mm)                                  213
# Body Mass (g)                                       5400
# Sex                                                 MALE
# Delta 15 N (o/oo)                                 8.3639
# Delta 13 C (o/oo)                               -26.1553
# Name: 343, dtype: object
# index : 343

# %%
for col in data:
    print(data[col])
# Out:
# 1      Adelie Penguin (Pygoscelis adeliae)
# 2      Adelie Penguin (Pygoscelis adeliae)
# 4      Adelie Penguin (Pygoscelis adeliae)
# 5      Adelie Penguin (Pygoscelis adeliae)
# 6      Adelie Penguin (Pygoscelis adeliae)
#                       ...
# 338      Gentoo penguin (Pygoscelis papua)
# 340      Gentoo penguin (Pygoscelis papua)
# 341      Gentoo penguin (Pygoscelis papua)
# 342      Gentoo penguin (Pygoscelis papua)
# 343      Gentoo penguin (Pygoscelis papua)
# Name: Species, Length: 325, dtype: object
# 1      Anvers
# 2      Anvers
# 4      Anvers
# 5      Anvers
# 6      Anvers
#         ...
# 338    Anvers
# 340    Anvers
# 341    Anvers
# 342    Anvers
# 343    Anvers
# Name: Region, Length: 325, dtype: object
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
# 6      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: Island, Length: 325, dtype: object
# 1      Adult, 1 Egg Stage
# 2      Adult, 1 Egg Stage
# 4      Adult, 1 Egg Stage
# 5      Adult, 1 Egg Stage
# 6      Adult, 1 Egg Stage
#               ...
# 338    Adult, 1 Egg Stage
# 340    Adult, 1 Egg Stage
# 341    Adult, 1 Egg Stage
# 342    Adult, 1 Egg Stage
# 343    Adult, 1 Egg Stage
# Name: Stage, Length: 325, dtype: object
# 1      Yes
# 2      Yes
# 4      Yes
# 5      Yes
# 6       No
#       ...
# 338     No
# 340    Yes
# 341    Yes
# 342    Yes
# 343    Yes
# Name: Clutch Completion, Length: 325, dtype: object
# 1      39.5
# 2      40.3
# 4      36.7
# 5      39.3
# 6      38.9
#        ...
# 338    47.2
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: Culmen Length (mm), Length: 325, dtype: float64
# 1      17.4
# 2      18.0
# 4      19.3
# 5      20.6
# 6      17.8
#        ...
# 338    13.7
# 340    14.3
# 341    15.7
# 342    14.8
# 343    16.1
# Name: Culmen Depth (mm), Length: 325, dtype: float64
# 1      186.0
# 2      195.0
# 4      193.0
# 5      190.0
# 6      181.0
#        ...
# 338    214.0
# 340    215.0
# 341    222.0
# 342    212.0
# 343    213.0
# Name: Flipper Length (mm), Length: 325, dtype: float64
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 5      3650.0
# 6      3625.0
#         ...
# 338    4925.0
# 340    4850.0
# 341    5750.0
# 342    5200.0
# 343    5400.0
# Name: Body Mass (g), Length: 325, dtype: float64
# 1      FEMALE
# 2      FEMALE
# 4      FEMALE
# 5        MALE
# 6      FEMALE
#         ...
# 338    FEMALE
# 340    FEMALE
# 341      MALE
# 342    FEMALE
# 343      MALE
# Name: Sex, Length: 325, dtype: object
# 1      8.94956
# 2      8.36821
# 4      8.76651
# 5      8.66496
# 6      9.18718
#         ...
# 338    7.99184
# 340    8.41151
# 341    8.30166
# 342    8.24246
# 343    8.36390
# Name: Delta 15 N (o/oo), Length: 325, dtype: float64
# 1     -24.69454
# 2     -25.33302
# 4     -25.32426
# 5     -25.29805
# 6     -25.21799
#          ...
# 338   -26.20538
# 340   -26.13832
# 341   -26.04117
# 342   -26.11969
# 343   -26.15531
# Name: Delta 13 C (o/oo), Length: 325, dtype: float64

# %%
myData = data
myData

'Sp'
# Out:
#                                  Species  Region     Island  \
# 1    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 5    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 6    Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..                                   ...     ...        ...
# 338    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 340    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 341    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 342    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 343    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#                   Stage Clutch Completion  Culmen Length (mm)  \
# 1    Adult, 1 Egg Stage               Yes                39.5
# 2    Adult, 1 Egg Stage               Yes                40.3
# 4    Adult, 1 Egg Stage               Yes                36.7
# 5    Adult, 1 Egg Stage               Yes                39.3
# 6    Adult, 1 Egg Stage                No                38.9
# ..                  ...               ...                 ...
# 338  Adult, 1 Egg Stage                No                47.2
# 340  Adult, 1 Egg Stage               Yes                46.8
# 341  Adult, 1 Egg Stage               Yes                50.4
# 342  Adult, 1 Egg Stage               Yes                45.2
# 343  Adult, 1 Egg Stage               Yes                49.9
#
#      Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)     Sex  \
# 1                 17.4                186.0         3800.0  FEMALE
# 2                 18.0                195.0         3250.0  FEMALE
# 4                 19.3                193.0         3450.0  FEMALE
# 5                 20.6                190.0         3650.0    MALE
# 6                 17.8                181.0         3625.0  FEMALE
# ..                 ...                  ...            ...     ...
# 338               13.7                214.0         4925.0  FEMALE
# 340               14.3                215.0         4850.0  FEMALE
# 341               15.7                222.0         5750.0    MALE
# 342               14.8                212.0         5200.0  FEMALE
# 343               16.1                213.0         5400.0    MALE
#
#      Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 1              8.94956          -24.69454
# 2              8.36821          -25.33302
# 4              8.76651          -25.32426
# 5              8.66496          -25.29805
# 6              9.18718          -25.21799
# ..                 ...                ...
# 338            7.99184          -26.20538
# 340            8.41151          -26.13832
# 341            8.30166          -26.04117
# 342            8.24246          -26.11969
# 343            8.36390          -26.15531
#
# [325 rows x 12 columns]

# %%
#transforming cols that are not floats and ints
le = preprocessing.LabelEncoder()

#species 
myData['Species'] = le.fit_transform(myData['Species'])
#regions
myData['Region'] = le.fit_transform(myData['Region'])
#island
myData['Island'] = le.fit_transform(myData['Island'])
#stage
myData['Stage'] = le.fit_transform(myData['Stage'])
#clutch competition
myData['Clutch Completion'] = le.fit_transform(myData['Clutch Completion'])
#sex
myData['Sex'] = le.fit_transform(myData['Sex'])
# Out:
# <ipython-input-62-15e984122d48>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['Species'] = le.fit_transform(myData['Species'])
# <ipython-input-62-15e984122d48>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['Region'] = le.fit_transform(myData['Region'])
# <ipython-input-62-15e984122d48>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['Island'] = le.fit_transform(myData['Island'])
# <ipython-input-62-15e984122d48>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['Stage'] = le.fit_transform(myData['Stage'])
# <ipython-input-62-15e984122d48>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['Clutch Completion'] = le.fit_transform(myData['Clutch Completion'])
# <ipython-input-62-15e984122d48>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   myData['Sex'] = le.fit_transform(myData['Sex'])

# %%
myData
# Out:
#      Species  Region  Island  Stage  Clutch Completion  Culmen Length (mm)  \
# 1          0       0       2      0                  1                39.5
# 2          0       0       2      0                  1                40.3
# 4          0       0       2      0                  1                36.7
# 5          0       0       2      0                  1                39.3
# 6          0       0       2      0                  0                38.9
# ..       ...     ...     ...    ...                ...                 ...
# 338        2       0       0      0                  0                47.2
# 340        2       0       0      0                  1                46.8
# 341        2       0       0      0                  1                50.4
# 342        2       0       0      0                  1                45.2
# 343        2       0       0      0                  1                49.9
#
#      Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  Sex  \
# 1                 17.4                186.0         3800.0    1
# 2                 18.0                195.0         3250.0    1
# 4                 19.3                193.0         3450.0    1
# 5                 20.6                190.0         3650.0    2
# 6                 17.8                181.0         3625.0    1
# ..                 ...                  ...            ...  ...
# 338               13.7                214.0         4925.0    1
# 340               14.3                215.0         4850.0    1
# 341               15.7                222.0         5750.0    2
# 342               14.8                212.0         5200.0    1
# 343               16.1                213.0         5400.0    2
#
#      Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 1              8.94956          -24.69454
# 2              8.36821          -25.33302
# 4              8.76651          -25.32426
# 5              8.66496          -25.29805
# 6              9.18718          -25.21799
# ..                 ...                ...
# 338            7.99184          -26.20538
# 340            8.41151          -26.13832
# 341            8.30166          -26.04117
# 342            8.24246          -26.11969
# 343            8.36390          -26.15531
#
# [325 rows x 12 columns]

# %%
x_slice = myData[['Region', 'Island', 'Stage', 'Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']]
y_slice = myData[['Species']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Region', 'Island', 'Stage', 'Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-78e5870d8b3c> in <module>
# ----> 1 x_slice = myData['Region', 'Island', 'Stage', 'Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']
#       2 y_slice = myData['Species']
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: ('Region', 'Island', 'Stage', 'Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)')

# %%
x_slice
# Out:
# ['Region',
#  'Island',
#  'Stage',
#  'Clutch Completion',
#  'Culmen Length (mm)',
#  'Culmen Depth (mm)',
#  'Flipper Length (mm)',
#  'Body Mass (g)',
#  'Sex',
#  'Delta 15 N (o/oo)',
#  'Delta 13 C (o/oo)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x_slice, y_slice, test_size = 0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-aab8dc3496a4> in <module>
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(x_slice, y_slice, test_size = 0.2)
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     290     """
#     291     result = [_make_indexable(X) for X in iterables]
# --> 292     check_consistent_length(*result)
#     293     return result
#     294
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [11, 1]
