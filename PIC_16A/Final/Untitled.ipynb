# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def new_circle(center, radius, c, s):
    print(center)
    print(radius)
    print(color)
    print(s)
    circle = plt.Circle(center, radius, c)
    #circle = plt.Circle((1001,1001), 500, color = 'r')
    ax.add_patch(circle)

# %%
n = 2001
i = np.ones([n,1,1]) * np.ones([1,n,1]) * np.ones([1,1,3])
i = i * np.array([0.5, 0, 0.5])

center = [(1001, 1001)]
#circle = plt.Circle((1001,1001), 500, color = 'r')


figure, ax = plt.subplots(1)
ax.imshow(i)
s = 1
new_circle((1001,1001), 500, 'r', s)
# Out:
# (1001, 1001)
# 500
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-30da369dd3dd> in <module>
#      10 ax.imshow(i)
#      11 s = 1
# ---> 12 new_circle((1001,1001), 500, 'r', s)
#
# <ipython-input-49-7ce105123752> in new_circle(center, radius, c, s)
#       2     print(center)
#       3     print(radius)
# ----> 4     print(color)
#       5     print(s)
#       6     circle = plt.Circle(center, radius, c)
#
# NameError: name 'color' is not defined

# %%
fig = plt.figure(figsize = (5,5))
x = np.linspace(0, 1.0, 100)
y = np.linspace(0, 1.0, 100)
X, Y = np.meshgrid(x,y)
#F = X**2 + Y**2 - 0.5
#plt.contour(X,Y,F,[0])
plt.show()

# %%
n
# Out:
# 2001

# %%
f = plt.figure(figsize = (5,5))
x1 = np.linspace(0, n, 100)
y1 = np.linspace(0, n, 100)
x1, y1 = np.meshgrid(x1,y1)
F = (x1-1000)**2 + (y1-1000)**2 
plt.contour(x1,y1,F)

# %%
x1
# Out:
# array([[   0.        ,   20.21212121,   40.42424242, ..., 1960.57575758,
#         1980.78787879, 2001.        ],
#        [   0.        ,   20.21212121,   40.42424242, ..., 1960.57575758,
#         1980.78787879, 2001.        ],
#        [   0.        ,   20.21212121,   40.42424242, ..., 1960.57575758,
#         1980.78787879, 2001.        ],
#        ...,
#        [   0.        ,   20.21212121,   40.42424242, ..., 1960.57575758,
#         1980.78787879, 2001.        ],
#        [   0.        ,   20.21212121,   40.42424242, ..., 1960.57575758,
#         1980.78787879, 2001.        ],
#        [   0.        ,   20.21212121,   40.42424242, ..., 1960.57575758,
#         1980.78787879, 2001.        ]])

# %%
np.linspace(0, n, 11)
# Out:
# array([   0. ,  200.1,  400.2,  600.3,  800.4, 1000.5, 1200.6, 1400.7,
#        1600.8, 1800.9, 2001. ])
