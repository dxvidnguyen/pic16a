# %%
#import libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import tree, preprocessing, metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.feature_selection import f_classif
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
import itertools

# %%
#penguins data
url = "https://philchodrow.github.io/PIC16A/datasets/palmer_penguins.csv"
penguins = pd.read_csv(url)

#dropping columns: studyName, Individual ID, Date Egg, Sample Number
pdata = penguins.drop(['studyName', 'Individual ID', 'Date Egg', 'Region', 'Sample Number', 'Comments'], axis = 1)

#drop nan values
mydata = pdata.dropna()

#get rid of penguin with period for sex
data = mydata.drop(mydata.index[318])

#transforming cols that are not floats and ints
le = preprocessing.LabelEncoder()

#species 
data['Species'] = le.fit_transform(data['Species'])
#island
data['Island'] = le.fit_transform(data['Island'])
#stage
data['Stage'] = le.fit_transform(data['Stage'])
#clutch competition
data['Clutch Completion'] = le.fit_transform(data['Clutch Completion'])
#sex
data['Sex'] = le.fit_transform(data['Sex'])

data.head(10)
# Out:
#     Species  Island  Stage  Clutch Completion  Culmen Length (mm)  \
# 1         0       2      0                  1                39.5
# 2         0       2      0                  1                40.3
# 4         0       2      0                  1                36.7
# 5         0       2      0                  1                39.3
# 6         0       2      0                  0                38.9
# 7         0       2      0                  0                39.2
# 14        0       2      0                  1                34.6
# 16        0       2      0                  1                38.7
# 17        0       2      0                  1                42.5
# 18        0       2      0                  1                34.4
#
#     Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  Sex  \
# 1                17.4                186.0         3800.0    0
# 2                18.0                195.0         3250.0    0
# 4                19.3                193.0         3450.0    0
# 5                20.6                190.0         3650.0    1
# 6                17.8                181.0         3625.0    0
# 7                19.6                195.0         4675.0    1
# 14               21.1                198.0         4400.0    1
# 16               19.0                195.0         3450.0    0
# 17               20.7                197.0         4500.0    1
# 18               18.4                184.0         3325.0    0
#
#     Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 1             8.94956          -24.69454
# 2             8.36821          -25.33302
# 4             8.76651          -25.32426
# 5             8.66496          -25.29805
# 6             9.18718          -25.21799
# 7             9.46060          -24.89958
# 14            8.55583          -25.22588
# 16            9.18528          -25.06691
# 17            8.67538          -25.13993
# 18            8.47827          -25.23319

# %%
#getting all possible combinations
names = list(data.columns)[1:]
combos = list(itertools.combinations(names, 3))
combos
# Out:
# [('Island', 'Stage', 'Clutch Completion'),
#  ('Island', 'Stage', 'Culmen Length (mm)'),
#  ('Island', 'Stage', 'Culmen Depth (mm)'),
#  ('Island', 'Stage', 'Flipper Length (mm)'),
#  ('Island', 'Stage', 'Body Mass (g)'),
#  ('Island', 'Stage', 'Sex'),
#  ('Island', 'Stage', 'Delta 15 N (o/oo)'),
#  ('Island', 'Stage', 'Delta 13 C (o/oo)'),
#  ('Island', 'Clutch Completion', 'Culmen Length (mm)'),
#  ('Island', 'Clutch Completion', 'Culmen Depth (mm)'),
#  ('Island', 'Clutch Completion', 'Flipper Length (mm)'),
#  ('Island', 'Clutch Completion', 'Body Mass (g)'),
#  ('Island', 'Clutch Completion', 'Sex'),
#  ('Island', 'Clutch Completion', 'Delta 15 N (o/oo)'),
#  ('Island', 'Clutch Completion', 'Delta 13 C (o/oo)'),
#  ('Island', 'Culmen Length (mm)', 'Culmen Depth (mm)'),
#  ('Island', 'Culmen Length (mm)', 'Flipper Length (mm)'),
#  ('Island', 'Culmen Length (mm)', 'Body Mass (g)'),
#  ('Island', 'Culmen Length (mm)', 'Sex'),
#  ('Island', 'Culmen Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Island', 'Culmen Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Island', 'Culmen Depth (mm)', 'Flipper Length (mm)'),
#  ('Island', 'Culmen Depth (mm)', 'Body Mass (g)'),
#  ('Island', 'Culmen Depth (mm)', 'Sex'),
#  ('Island', 'Culmen Depth (mm)', 'Delta 15 N (o/oo)'),
#  ('Island', 'Culmen Depth (mm)', 'Delta 13 C (o/oo)'),
#  ('Island', 'Flipper Length (mm)', 'Body Mass (g)'),
#  ('Island', 'Flipper Length (mm)', 'Sex'),
#  ('Island', 'Flipper Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Island', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Island', 'Body Mass (g)', 'Sex'),
#  ('Island', 'Body Mass (g)', 'Delta 15 N (o/oo)'),
#  ('Island', 'Body Mass (g)', 'Delta 13 C (o/oo)'),
#  ('Island', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Island', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Island', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Clutch Completion', 'Culmen Length (mm)'),
#  ('Stage', 'Clutch Completion', 'Culmen Depth (mm)'),
#  ('Stage', 'Clutch Completion', 'Flipper Length (mm)'),
#  ('Stage', 'Clutch Completion', 'Body Mass (g)'),
#  ('Stage', 'Clutch Completion', 'Sex'),
#  ('Stage', 'Clutch Completion', 'Delta 15 N (o/oo)'),
#  ('Stage', 'Clutch Completion', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Culmen Length (mm)', 'Culmen Depth (mm)'),
#  ('Stage', 'Culmen Length (mm)', 'Flipper Length (mm)'),
#  ('Stage', 'Culmen Length (mm)', 'Body Mass (g)'),
#  ('Stage', 'Culmen Length (mm)', 'Sex'),
#  ('Stage', 'Culmen Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Stage', 'Culmen Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Culmen Depth (mm)', 'Flipper Length (mm)'),
#  ('Stage', 'Culmen Depth (mm)', 'Body Mass (g)'),
#  ('Stage', 'Culmen Depth (mm)', 'Sex'),
#  ('Stage', 'Culmen Depth (mm)', 'Delta 15 N (o/oo)'),
#  ('Stage', 'Culmen Depth (mm)', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Flipper Length (mm)', 'Body Mass (g)'),
#  ('Stage', 'Flipper Length (mm)', 'Sex'),
#  ('Stage', 'Flipper Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Stage', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Body Mass (g)', 'Sex'),
#  ('Stage', 'Body Mass (g)', 'Delta 15 N (o/oo)'),
#  ('Stage', 'Body Mass (g)', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Stage', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Stage', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Clutch Completion', 'Culmen Length (mm)', 'Culmen Depth (mm)'),
#  ('Clutch Completion', 'Culmen Length (mm)', 'Flipper Length (mm)'),
#  ('Clutch Completion', 'Culmen Length (mm)', 'Body Mass (g)'),
#  ('Clutch Completion', 'Culmen Length (mm)', 'Sex'),
#  ('Clutch Completion', 'Culmen Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Clutch Completion', 'Culmen Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Clutch Completion', 'Culmen Depth (mm)', 'Flipper Length (mm)'),
#  ('Clutch Completion', 'Culmen Depth (mm)', 'Body Mass (g)'),
#  ('Clutch Completion', 'Culmen Depth (mm)', 'Sex'),
#  ('Clutch Completion', 'Culmen Depth (mm)', 'Delta 15 N (o/oo)'),
#  ('Clutch Completion', 'Culmen Depth (mm)', 'Delta 13 C (o/oo)'),
#  ('Clutch Completion', 'Flipper Length (mm)', 'Body Mass (g)'),
#  ('Clutch Completion', 'Flipper Length (mm)', 'Sex'),
#  ('Clutch Completion', 'Flipper Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Clutch Completion', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Clutch Completion', 'Body Mass (g)', 'Sex'),
#  ('Clutch Completion', 'Body Mass (g)', 'Delta 15 N (o/oo)'),
#  ('Clutch Completion', 'Body Mass (g)', 'Delta 13 C (o/oo)'),
#  ('Clutch Completion', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Clutch Completion', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Clutch Completion', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)'),
#  ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Body Mass (g)'),
#  ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Sex'),
#  ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Delta 15 N (o/oo)'),
#  ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Delta 13 C (o/oo)'),
#  ('Culmen Length (mm)', 'Flipper Length (mm)', 'Body Mass (g)'),
#  ('Culmen Length (mm)', 'Flipper Length (mm)', 'Sex'),
#  ('Culmen Length (mm)', 'Flipper Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Culmen Length (mm)', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Culmen Length (mm)', 'Body Mass (g)', 'Sex'),
#  ('Culmen Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)'),
#  ('Culmen Length (mm)', 'Body Mass (g)', 'Delta 13 C (o/oo)'),
#  ('Culmen Length (mm)', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Culmen Length (mm)', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Culmen Length (mm)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)'),
#  ('Culmen Depth (mm)', 'Flipper Length (mm)', 'Sex'),
#  ('Culmen Depth (mm)', 'Flipper Length (mm)', 'Delta 15 N (o/oo)'),
#  ('Culmen Depth (mm)', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'),
#  ('Culmen Depth (mm)', 'Body Mass (g)', 'Sex'),
#  ('Culmen Depth (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)'),
#  ('Culmen Depth (mm)', 'Body Mass (g)', 'Delta 13 C (o/oo)'),
#  ('Culmen Depth (mm)', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Culmen Depth (mm)', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Culmen Depth (mm)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Flipper Length (mm)', 'Body Mass (g)', 'Sex'),
#  ('Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)'),
#  ('Flipper Length (mm)', 'Body Mass (g)', 'Delta 13 C (o/oo)'),
#  ('Flipper Length (mm)', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Flipper Length (mm)', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Flipper Length (mm)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Body Mass (g)', 'Sex', 'Delta 15 N (o/oo)'),
#  ('Body Mass (g)', 'Sex', 'Delta 13 C (o/oo)'),
#  ('Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)'),
#  ('Sex', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)')]

# %%
#using tree to select cols 
def check_column_score(cols):
    """
    Trains and evaluates a model via cross-validation on the columns of the data
    with selected indices
    """
    T = tree.DecisionTreeClassifier(max_depth = 5)
    return cross_val_score(T, x_train[cols], y_train, cv = 5).mean()  


def test_column_score(tupCol):
    """
    Trains and evaluates a model on the test set using the columns of the data
    with selected indices
    """
    cols = list(tupCol)
    T = tree.DecisionTreeClassifier(max_depth = 5)
    T.fit(x_train[cols], y_train)
    return T.score(x_test[cols], y_test)

# %%
#split into test and training data
train, test = train_test_split(data, test_size = 0.3)
train.shape, test.shape

x_train = train.drop(['Species'], axis = 1)
y_train = train['Species'].values

x_test = test.drop(['Species'], axis = 1)
y_test = test['Species'].values

# %%
#dict with cross value score of each combination 
D = {}

for i in range(len(combos)): 
    cols = list(combos[i])
    x = check_column_score(cols)
    D[i] = x

# %%
#sort dict
L = list(D.items())
L.sort(key = lambda tup: tup[1], reverse = True)

#show 10 best scores
best = L[0:10]

for where, score in best:
    print("---- " + str(where))
    print(str(combos[where]) + ", Score: " + str(np.round(score, 5)))
    test_score = test_column_score(combos[where])
    print("Test score is: " + str(np.round(test_score, 5)))
# Out:
# ---- 29
# ('Island', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'), Score: 0.97353
# Test score is: 0.92857
# ---- 15
# ('Island', 'Culmen Length (mm)', 'Culmen Depth (mm)'), Score: 0.96889
# Test score is: 0.9898
# ---- 16
# ('Island', 'Culmen Length (mm)', 'Flipper Length (mm)'), Score: 0.96
# Test score is: 0.96939
# ---- 86
# ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Body Mass (g)'), Score: 0.95594
# Test score is: 0.96939
# ---- 18
# ('Island', 'Culmen Length (mm)', 'Sex'), Score: 0.95565
# Test score is: 0.96939
# ---- 103
# ('Culmen Depth (mm)', 'Flipper Length (mm)', 'Delta 13 C (o/oo)'), Score: 0.9514
# Test score is: 0.92857
# ---- 91
# ('Culmen Length (mm)', 'Flipper Length (mm)', 'Sex'), Score: 0.9513
# Test score is: 0.95918
# ---- 85
# ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)'), Score: 0.95121
# Test score is: 0.95918
# ---- 89
# ('Culmen Length (mm)', 'Culmen Depth (mm)', 'Delta 13 C (o/oo)'), Score: 0.94705
# Test score is: 0.9898
# ---- 19
# ('Island', 'Culmen Length (mm)', 'Delta 15 N (o/oo)'), Score: 0.94667
# Test score is: 0.94898

# %%
#best one is island, culmen depth, culmen length
X_train = train[list(combos[15])]
X_test = test[list(combos[15])]

# %%
#test out best depth for tree
fig, ax = plt.subplots(1, figsize = (10, 7))

best_score = 0

for d in range(1,30):
    T = tree.DecisionTreeClassifier(max_depth = d)
    cv_score = cross_val_score(T, X_train, y_train, cv=10).mean()
    ax.scatter(d, cv_score, color = "black")
    
    if cv_score > best_score:
        best_depth = d
        best_score = cv_score

l = ax.set(title = "Best Depth : " + str(best_depth),
       xlabel = "Depth", 
       ylabel = "CV Score")

# %%
best_score
# Out:
# 0.9867588932806324

# %%
#decision tree model
T = tree.DecisionTreeClassifier(max_depth = best_depth)
T.fit(X_train, y_train)
T.score(X_test, y_test)
# Out:
# 0.9897959183673469

# %%
fig, ax = plt.subplots(1, figsize = (10, 10))
p = tree.plot_tree(T, 
                   filled = True, 
                   feature_names = penguins.drop(['Species'], axis = 1).columns)

# %%
#test best complexity for logistic regresssion
fig, ax = plt.subplots(1, figsize = (10, 7))
lr_best_score = 0

#comp is short for complexity 
for comp in np.linspace(0.1, 1.1, 21):
    #range(1,30)
    logreg = LogisticRegression(max_iter = 1000, C = comp)
    cv_score = cross_val_score(logreg, X_train, y_train, cv=10).mean()
    ax.scatter(comp, cv_score, color = "black")
    
    if cv_score > lr_best_score:
        best_comp = comp
        lr_best_score = cv_score
    
    
l = ax.set(title = "Best Complexity : " + str(best_comp),
       xlabel = "Complexity", 
       ylabel = "CV Score")

# %%
#training lr model
lr = LogisticRegression(max_iter = 1000, C = best_comp)
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.9693877551020408

# %%
#MLP best depth
fig, ax = plt.subplots(1)
mlp_best_score = 0

# For 30 depths, find the highest score to find the best depth
for d in range(1,30):
    clf = MLPClassifier(hidden_layer_sizes=(d, d, d), max_iter=3000)
    cv_score = cross_val_score(clf, X_train, y_train, cv=10).mean()
    ax.scatter(d, cv_score, color = "black")
    if cv_score > mlp_best_score:
        mlp_best_depth = d
        mlp_best_score = cv_score
        
l = ax.set(title = "Best Depth : " + str(mlp_best_depth),
xlabel = "Depth",
ylabel = "CV Score")

# %%
# Train an MLPClassifier at best complexity, and evaluate the model on the test set

clf = MLPClassifier(hidden_layer_sizes=(18, 18, 18), max_iter=3000).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9795918367346939

# %%
clf.fit(X_train, y_train)
y_train_pred = clf.predict(X_train)
c = confusion_matrix(y_train, y_train_pred)

disp = plot_confusion_matrix(clf, X_test, y_test, cmap = plt.cm.Blues)

# %%
penguins['Species'] = penguins['Species'].str.split().str.get(0)

# %%
fig, ax = plt.subplots(1)
species = set(penguins['Species'])
ax.set(xlabel = 'Length',
       ylabel = 'Density')

for s in species: 
    i = penguins[penguins['Species'] == s]
    ax.hist(i['Culmen Length (mm)'], label = s, alpha= 0.5)
ax.legend()

# %%
fig, ax = plt.subplots(1)
species = set(penguins['Species'])
location = set(penguins['Island'])

ax.set(xlabel = 'Length',
       ylabel = 'Density')

for s in species: 
    i = penguins[penguins['Species'] == s]
    for l in location:
        t = i[i['Island'] == l]
        ax.hist(t['Culmen Length (mm)'], label = str(s + ', ' + l), alpha = 0.5)

ax.legend()

# %%
fig, ax = plt.subplots(1)
species = set(penguins['Species'])

for s in species:
    i = penguins[penguins['Species'] == s]
    ax.scatter(i[''], i['Culmen Depth (mm)'], label = s)
    
ax.legend()

ax.set(xlabel = 'Culmen Length (mm)',
       ylabel = 'Culmen Deotoh (mm)')
# Out:
# [Text(0.5, 0, 'Culmen Length (mm)'), Text(0, 0.5, 'Culmen Deotoh (mm)')]
